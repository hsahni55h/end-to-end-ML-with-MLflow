# %% [markdown]
# # Wine Quality — EDA
#
# Data source: `projects/01_wine_quality/data/raw/winequality-data.zip` (UCI Wine Quality — red, DVC-tracked), loaded the same way `WineQualityIngestor` reads it in `projects/01_wine_quality/ingestion.py` (comma-separated, extracted `winequality-red.csv`).

# %%
import pandas as pd

DATA_PATH = "../../projects/01_wine_quality/data/raw/winequality-data.zip"

df = pd.read_csv(DATA_PATH)
df.head()

# %% [markdown]
# ## Shape & dtypes

# %% [markdown]
# ## Missing values

# %% [markdown]
# ## Target distribution

# %% [markdown]
# ## Correlations

# %% [markdown]
# ## Outliers
